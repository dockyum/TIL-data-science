# %% [markdown]
# # HTML 데이터 파싱을 이용한 크롤링
# ## 1. 네이버 연관검색어
#     - 1. 웹페이지 분석 : URL 찾기
#     - 2. 요청 -> 응답 : HTML(str)
#     - 3. HTML(str) -> BeautifulSoup obj (css-selector) --> DF

# %%
from bs4 import BeautifulSoup

import requests

# %%
# 1. 웹페이지 분석 : URL
query = "삼성전자"

url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query={}".format(query)

print(url)
# Out:
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=삼성전자

# %%
# 2. request - > response : HTML(str)
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# 3. HTML(str) -> BeautifulSoup Obj (css - selector) -> DF
dom = BeautifulSoup(response.content, "html.parser")
dom
# Out:
# <!DOCTYPE html>
#  <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="삼성전자 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'삼성전자'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'삼성전자'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>삼성전자 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_201223.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_201223.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_201112.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCStri ...
# 	(function() {
# 		var startApplication = function() {
# 			var isChecked = nx_set_option_switch(naver.search.option.mson) ;
# 			var jsFileURL = "https://ssl.pstatic.net/sstatic/au/pc/search_option/SearchOption_201028_a.js" ;
# 			var require = window.require.config({
# 			 "context": "search_option",
# 			 "paths": {
# 				"SearchOption": jsFileURL.replace(/\.js$/, "")
# 				}
# 			});
# 			define("jquery", [], function() { return jQuery; });
# 			require(["SearchOption"], function(SearchOption) {
# 				/** [AU] 옵션 레이어 초기화
# 				* 초기화 할 필요가 없는 옵션의 경우 초기화 옵션객체를 생략 하시면 됩니다.
# 				* ex. 상세옵션 초기화가 필요할 때 { open: true, detail: {...} }
# 				*     상세옵션 초기화가 필요 없을 때 { open: false }
# 				*/
# 				var searchOption = new SearchOption(
# 					jQuery("#search_option_button")[0],
# 					jQuery("#snb")[0],
# 					{
# 						"open": false,
# 						"openCookie": "nso_open",
# 						"persist": {/* 옵션유지 초기화 */
# 					              "isChecked": isChecked /* 체크된 상태 */
# 						 }
# 						, "detail": { "base": "삼성전자", "or": false, "exact": [], "include": [], "exclude": [] }
# 					}
# 				).on({
# 				/* [AU] 옵션유지 클릭시 */
# 				"change-persist": function (e) {
# 					nx_set_option_switch(e.isChecked);
# 					tCR(e.isChecked ? "a=fno.mson" : "a=fno.msoff");
# 				}
# 				, "detail-submit": function (e) { var elForm = jQuery("#nx_search_form")[0]; if (!elForm) { return; } if (elForm.sm) { elForm.sm.value = "tab_dts"; } if (elForm.query) { elForm.query.value = e.form.preview; } if (elForm.qdt) { elForm.qdt.value = "1"; elForm.qdt.disabled = false; } window.naver && naver.search && naver.search.option && naver.search.option && naver.search.option.append_params && naver.search.option.append_params(elForm); elForm.submit(); }
# 			});
# 		});
# 	};
#
# 	naver.common.load_js(window.require ? null : naver.common.gv.REQUIRE_JS, startApplication, true, 150);
#   })();
# </script>
# <script> (function() { var startApplication = function() { var jsFileURL = "https://ssl.pstatic.net/sstatic/au/pc/tab/SearchTab_201028.js"; var require = window.require.config({ "context": "search_tab_module", "paths": { "SearchTab": jsFileURL.replace(/\.js$/, ""), } }); define("jquery", [], function() { return jQuery; }); require(["SearchTab"], function(SearchTab) { var BASE_FLOATING_WIDTH = 1181; var $window = jQuery(window); var $lnb = jQuery("#lnb"); var $headerWrap = jQuery("#header_wrap"); var tab = new SearchTab($window, $lnb) .on("checkWindowWidth", function(e){ if (e.windowWidth >= BASE_FLOATING_WIDTH) { $headerWrap.addClass("type_fixed"); tab.activateFloating(); } else { tab.deactivateFloating(); $headerWrap .removeClass("type_fixed") .removeClass("type_hide"); } }) .on("hideTab", function(){ if (window.g_nx_splugin && typeof window.g_nx_splugin.hide === "function") { window.g_nx_splugin.hide(); } }) .on("changeState", function(e){ $headerWrap.toggleClass("type_hide", e.isUnderBaseline); if (e.isUnderBaseline) { $headerWrap.addClass("type_animation"); } }); }); }; naver.common.load_js(window.require ? null : naver.common.gv.REQUIRE_JS, startApplication, true, 150); })(); </script><script type="text/javascript"> naver.search.section = { "main": [{"area": "vsd_com*c", "rank": 1},{"area": "pwl_nop", "rank": 2},{"area": "nco_x0l*1", "rank": 3},{"area": "nws_all*hcdip", "rank": 4},{"area": "shp_gui*a539", "rank": 5},{"area": "kdc_gng*DMW", "rank": 6},{"area": "bok_2nd", "rank": 7},{"area": "web_gen*w", "rank": 8},{"area": "biz_nop", "rank": 9}], "main2": [{"area": "rsk_top*q", "rank": 1},{"area": "cop_nam", "rank": 2},{"area": "nco_x7f*1", "rank": 3},{"area": "htk", "rank": 4}],  "find_section_list": function(column, area) { if (!this[column]) return []; return this[column].filter(function(a) { return a.area.indexOf(area) === 0; }); } }; </script></div><script type="text/javascript"> var nx_location_rcode = "09560132" ; </script><div id="container" role="main"> <div class="pack_group" id="content"> <h1 class="blind">삼성전자 통합검색 결과</h1> <div class="main_pack" id="main_pack"><script type="text/javascript">var nx_cr_area_info=[{ n:"vsd_com",r:1 },{ n:"pwl_nop",r:2 },{ n:"nco_x0l",r:3 },{ n:"nws_all",r:4 },{ n:"shp_gui",r:5 },{ n:"kdc_gng",r:6 },{ n:"bok_2nd",r:7 },{ n:"web_gen",r:8 },{ n:"biz_nop",r:9 }];</script><section class="sc_new sp_nsite _section_nsite_ _sp_ntotal"> <div class="api_subject_bx _nsiteBase"> <div class="nsite_info"> <div class="nsite_tit"> <div class="nsite_link"> <div class="nsite_source"> <a class="link_source elss" href="https://www.samsung.com/" onclick="return goOtherCR(this, 'a=vsd_com.purl&amp;r=1&amp;i=a00000fa_10c3851587074e98ecb97e6c&amp;u='+urlencode(this.href))" target="_blank"> <span class="thumb"><img alt="" height="15" src="https://search.pstatic.net/sunny/?src=https%3A%2F%2Fwww.samsung.com%2Fsec%2Fstatic%2F_images%2Ffavicon.ico&amp;type=f30_30_expire24" width="15"/></span><span class="source_url">www.samsung.com</span> </a> </div> <div class="nsite_name"> <div class="ico_wrap"> </div> <a class="link_name" href="https://www.samsung.com/" onclick="return goOtherCR(this, 'a=vsd_com.tit&amp;r=1&amp;i=a00000fa_10c3851587074e98ecb97e6c&amp;u='+urlencode(this.href))" target="_blank"><b class="hl">삼성전자</b></a> </div> </div> </div> <div class="nsite_desc"> <div class="sublink_wrap"> <ul class="sublink"><li class="item"><a href="https://www.samsung.com/sec/membership/point/" onclick="return goOtherCR(this, 'a=vsd_com.sitsub&amp;r=1&amp;i=a00000fa_10c3851587074e98ecb97e6c&amp;u='+urlencode(this.href))" target="_blank">나의 정보</a></li><li class="item"><a href="https://www.samsung.com/sec/digitalplaza/storeMain/" onclick="return goOtherCR(this, 'a=vsd_com.sitsub&amp;r=2&amp;i=a00000fa_10c3851587074e98ecb97e6c&amp;u='+urlencode(this.href))" target="_blank">매장 찾기</a></li><li class="item"><a href="https://www.samsung.com/sec/digitalplaza/centerMain/" onclick="return goOtherCR(this, 'a=vsd_com.sitsub&amp;r=3& ...
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/201106/css/powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">삼성전자</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=wPKNtuSOfqadk2ZSCmhJ2t_fvA9Rh5sRwql5If5_...">
# <ul class="lst_type">
# <li class="lst lst1 ext_link" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=Y5zWtWF0VcKvph9kgycGt////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">G마켓 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Y5zWtWF0VcKvph9kgycGt////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.gmarket.co.kr</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=YW4ibAVo42bEnIuc50U1x////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">베스트상품</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=FMdiHBncEXzSl3xLLPW5Ef///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">슈퍼딜</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=gxIeNt7xpf6W9VNIId7O9////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">당일배송</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=NktAs/zZzhyWADWEMC0J2v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000097768375&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">쿠폰존</a>
# </li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               쇼핑을 바꾸는 쇼핑! <strong class="hl">삼성전자</strong> 스마일클럽은 12% 할인 + 스마일배송 무료배송
#             </p></div>
# </div>
# </li>
# <li class="lst lst2 ext_desc" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=Onje3Y1ITNozQAFtal7PrP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000109044012&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">삼성전자 티몬</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Onje3Y1ITNozQAFtal7PrP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000109044012&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000109044012&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <p class="ad_dsc promotion">
# <em class="point">추가선물증정</em>
#               스타벅스 아메리카노 증정!
#             </p>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">삼성전자</strong>, 각종 최신 인기가전/디지털제품, 렌탈, 구입까지! 합리적가격+추가할인
#             </p></div>
# </div>
# </li>
# <li class="lst lst3 ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=zA/R2dcz4rec1zRYosbQ0f///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA4MjNfMjcz/MDAxNTY2NTM3NTQyMTQ0.i-5sGL15or_1DXb__k5O2ea7OQGCzGQI5JuCxSgPyjwg.Ah_0BrfJDwPgcrZ_h-NbQjC6qcv--lLNBjuWQ2IloV0g.PNG/200016-66a70c22-44e5-431b-99dd-d1056ce1a79c.png?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=mCaFS/aaYisf7EiPPEublf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d=' + urlencode('http://shinsegaemall.ssg.com') + '&amp;u='+ urlencode(this.href));" target="_blank">신세계몰 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=mCaFS/aaYisf7EiPPEublf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">shinsegaemall.ssg.com</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=ZnAg2lXfrUz3oHZSzItyJ////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">오늘의 특가</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=yWy1xOEApBsmZb54z8Lyfv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">인기 신상품</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=OsX7hjiNEidnfO+z85jZjf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">공식스토어</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=EXDnPCf03iP2dd86rjPgf////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000101553089&amp;d='+urlencode('http://shinsegaemall.ssg.com')+'&amp;u='+urlencode(this.href));" target="_blank">베스트100</a>
# </li>
# </ul>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               삶의 질을 높여줄 가전 브랜드, <strong class="hl">삼성전자</strong>, 7%청구할인+할인쿠폰 쓱.
#             </p></div>
# </div>
# </li>
# <li class="lst lst4 type_img" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=FQAnYziy5ntdfjnSVwx6Yf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000113016521&amp;d='+urlencode('http://www.imarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTExMDFfMTY4/MDAxNTcyNTgzNzE1NTc4.kquA1apRADluEusJUpTnUR4XU1mmdg5SKA00rleZIlIg.cgrpV5M97MYaua3NYtwJnAFUlZcRDZ5lfCd4wNc4_4Qg.JPEG/1273007-1db3f143-d636-476a-a9a2-506c95c8fa30.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=ymrn5EpC5jP7bJrIBfWUXf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000113016521&amp;d=' + urlencode('http://www.imarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">사업자용 삼성전자 아이마켓</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ymrn5EpC5jP7bJrIBfWUXf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000113016521&amp;d='+urlencode('http://www.imarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.imarket.co.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=4&amp;i=nad-a001-01-000000113016521&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               산업재 전문몰, 신규가입 3만원 할인, 무료배송, 오늘출고, <strong class="hl">삼성전자</strong>
# </p></div>
# </div>
# </li>
# <li class="lst lst5 ext_desc type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=Qvc6sTWacZ7CbO7vc/r9Qf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000082647016&amp;d='+urlencode('http://first-rental.net')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA1MTVfMjc5/MDAxNTU3OTA0MjE4NDk0.kr2njDjfPithwdXuH_H0GftQSiCwWWrJ0ANwT7xpDSMg.9-CjBX4iUCtdpET13OqbzhFDT2oSMmMbOnZBA0e7klMg.PNG/1459054-bd7ec4da-7290-4389-85ec-68cace863412.png?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=2RLHwZe/jaaO9ag6vQONkP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000082647016&amp;d=' + urlencode('http://first-rental.net') + '&amp;u='+ urlencode(this.href));" target="_blank">LG헬로 삼성전자렌탈 특가</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=2RLHwZe/jaaO9ag6vQONkP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000082647016&amp;d='+urlencode('http://first-rental.net')+'&amp;u='+urlencode(this.href));" target="_blank">first-rental.net</a>
# </div>
# <p class="ad_dsc promotion">
# <em class="point">이벤트</em>
#               2주간 사은품 대박혜택!
#             </p>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               푸짐한사은품, 삼성 인기가전 초기비용 0원, 배송비설치비무료, 만기후 소유권이전
#             </p></div>
# </div>
# </li>
# <li class="lst lst6" num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="line"></div>
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=lp0dUjnuAxagN7CVqjPxZ////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000116993228&amp;d=' + urlencode('http://www.시스템에어컨삼성.com') + '&amp;u='+ urlencode(this.href));" target="_blank">삼성시스템에어컨 전문점</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=lp0dUjnuAxagN7CVqjPxZ////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000116993228&amp;d='+urlencode('http://www.시스템에어컨삼성.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.시스템에어컨삼성.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               고급주택, 아파트 시스템에어컨/사무실,상가 천장형냉난방기/판매 및 설치/착한가격
#             </p></div>
# </div>
# </li>
# <li class="lst lst7" num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=ZZD78+tLWjzMDRrc+PsW0v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000101525500&amp;d=' + urlencode('http://WWW.SSG.COM') + '&amp;u='+ urlencode(this.href));" target="_blank">SSG닷컴 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ZZD78+tLWjzMDRrc+PsW0v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000101525500&amp;d='+urlencode('http://WWW.SSG.COM')+'&amp;u='+urlencode(this.href));" target="_blank">WWW.SSG.COM</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000101525500&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               마음에 쓱 드는 쇼핑! <strong class="hl">삼성전자</strong>, 백화점에서 이마트까지 한번에 쓱, 카드청구할인.
#             </p></div>
# </div>
# </li>
# <li class="lst lst8" num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=0H1SM885bRR1mh6DSqWe3P///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000046468195&amp;d=' + urlencode('http://www.enuri.com') + '&amp;u='+ urlencode(this.href));" target="_blank">삼성전자 에누리 가격비교</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=0H1SM885bRR1mh6DSqWe3P///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000046468195&amp;d='+urlencode('http://www.enuri.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.enuri.com</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=8&amp;i=nad-a001-01-000000046468195&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               에누리 찍고 구매시 8.3% 추가할인! 앱 구매시 e머니 추가적립! <strong class="hl">삼성전자</strong>
# </p></div>
# </div>
# </li>
# <li class="lst lst9" num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=pNkws6wkB8nkmZaGQztBff///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000114293020&amp;d=' + urlencode('http://www.skstoa.com') + '&amp;u='+ urlencode(this.href));" target="_blank">삼성전자 SK스토아</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=pNkws6wkB8nkmZaGQztBff///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000114293020&amp;d='+urlencode('http://www.skstoa.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.skstoa.com</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=9&amp;i=nad-a001-01-000000114293020&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">삼성전자</strong> 매장에서 봤다면 구매는 여기서, 12월만 4/9/16만원 적립!
#             </p></div>
# </div>
# </li>
# <li class="lst lst10" num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=FE6I3poLcJc5imat7Tk1x////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000099371934&amp;d=' + urlencode('http://www.lfmall.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">LF몰 리빙 라이프스타일</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=FE6I3poLcJc5imat7Tk1x////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000099371934&amp;d='+urlencode('http://www.lfmall.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.lfmall.co.kr</a>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=10&amp;i=nad-a001-01-000000099371934&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               인테리어 효과만점! 실내분위기를 한층 더 UP해주는 생활용품, LF몰 다수입점
#             </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;referenceId=U%2BEqVsp0YidsshOXTsKssssssqd-494659" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_ad"></i></a>
# </div>
# </div>
# <a class="ad_banner" href="https://help.pay.naver.com/faq/content.help?faqId=3150" onclick="return goOtherCR(this, 'a=mib_pwl.banner&amp;r=0&amp;i=mib_pwlbanner&amp;u='+urlencode(this.href));" target="_blank">
# <span class="sp_ad ico_npay">네이버페이</span><em class="txt_reward">3%</em>파워링크에서 구매 시 네이버페이로 결제하면 3% 적립
#     </a>
# </div>
# <script type="text/javascript">var g_uad = false; </script><link href="https://ssl.pstatic.net/sstatic/keypage/outside/scui/stock/css/pcs_stock_201027.css" rel="stylesheet" type="text/css"> <section class="sc_new cs_stock" data-dss-logarea="x0l"> <div class="api_subject_bx"> <div class="api_title_area" id="header"> <h3 class="api_title">증권정보</h3> </div> <div class="api_cs_wrap" id="_cs_root"></div> </div> </section> <script id="_cs_stock_item_template" type="text/template"> <div class="ar_spot"> <div class="spt_tlt"> <h3> <a nocr onclick="return goOtherCR(this, 'a=nco_x0l*1.titlay&r=1&i=18000004_0000001A6334&u=' + urlencode(this.href));" href="http://finance.naver.com/item/main.nhn?code={=itemCode}" target="_blank"><span class="stk_nm">{=itemName}</span><em class="t_nm">{=itemCode}</em> <span class="spt_con {js =htUtil.fGetClassName((=risefall))}"> <span class="blind">지수</span><strong>{js =fFormat("#,##0.#", (=priceLast))}</strong> <span class="n_ch"> <span class="blind">전일대비</span> <span class="ico">{js =htUtil.fGetCaption((=risefall))}</span> <em>{js =fFormat("#,##0.#", Math.abs(=priceChange))}</em> <em>({js =htUtil.fGetMark((=risefall)) + Math.abs(=priceChangeRate)}%)</em> </span> </span> </a> </h3> <div class="my_stock"> <a nocr onclick="return goOtherCR(this, 'a=nco_x0l*1.myadd&r=1&i=18000004_0000001A6334&u=' + urlencode(this.href));" href="http://finance.naver.com/item/main.nhn?code={=itemCode}&openAddMyStock=true" target="_blank" class="btn_my">MY등록</a> </div> </div> </div> <div class="ar_cont"> <div class="cont_grp"> <div class="grp_nav"> <h4 class="blind">기간별 정보</h4> <ul> <li class="on"><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.cht1d&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/day/{=itemCode}_search.png?sidcode=1397739283538" href="#">1일</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.cht3m&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/area/month3/{=itemCode}_search.png?sidcode=1398073782866" href="#">3개월</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.cht1y&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/area/year/{=itemCode}_search.png?sidcode=1398073782866" href="#">1년</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.cht3y&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/area/year3/{=itemCode}_search.png?sidcode=1398073782866" href="#">3년</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.cht10y&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/area/year10/{=itemCode}_search.png" href="#">10년</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.chtd&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/candle/day/{=itemCode}_search.png?sidcode=1398073782866" href="#">일봉</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.chtw&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/candle/week/{=itemCode}_search.png?sidcode=1398073782866" href="#">주봉</a></li> <li><a nocr onclick="goOtherTCR(this, 'a=nco_x0l*1.chtm&r=1&i=18000004_0000001A6334');return false;" class="_stock_chart_btn" data-chart-src="https://ssl.pstatic.net/imgfinance/chart/mobile/candle/month/{=itemCode}_search.png?sidcode=1398073782866" href="#">월봉</a></li> </ul> </div> <div class="grp_img"> <div class="img"> <a nocr onclick="return goOtherCR(this, 'a=nco_x0l*1.chtg&r=1&i=18000004_0000001A6334&u=' + urlencode(this.href));" href="http://finance.naver.com/item/fchart.nhn?code={=itemCode}" target="_blank"> <im ...
# <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <script type="text/javascript">
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">삼성전자</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=J3_e5vsQCrs5djDZa84pxmHKN9Wv1VO5Wp2L3k32_...">
# <ul class="lst_type">
# <li class="lst lst1" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=AwLeY6yiLa4n7cU0ZXOnBf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000098437461&amp;d=' + urlencode('http://www.lotteimall.com') + '&amp;u='+ urlencode(this.href));" target="_blank">롯데홈쇼핑 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=AwLeY6yiLa4n7cU0ZXOnBf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000098437461&amp;d='+urlencode('http://www.lotteimall.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteimall.com</a>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=1&amp;i=nad-a001-01-000000098437461&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               CREATE THE NEW 새로운 일상의 시작
#             </p></div>
# </div>
# </li>
# <li class="lst lst2" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=TW32N3aout7rqJmQ2vUNmP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000104256395&amp;d=' + urlencode('http://www.cjmall.com') + '&amp;u='+ urlencode(this.href));" target="_blank">CJmall 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=TW32N3aout7rqJmQ2vUNmP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000104256395&amp;d='+urlencode('http://www.cjmall.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.cjmall.com</a>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=2&amp;i=nad-a001-01-000000104256395&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               TV쇼핑 <strong class="hl">삼성전자</strong>, 가전은 믿을 수 있는 CJ몰에서! 카드5%할인+적립금까지
#             </p></div>
# </div>
# </li>
# <li class="lst lst3" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=5h9R95eV4Q1IyNdtms9uP////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000101062343&amp;d=' + urlencode('http://www.shinsegaetvshopping.com') + '&amp;u='+ urlencode(this.href));" target="_blank">신세계TV쇼핑 삼성전자</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=5h9R95eV4Q1IyNdtms9uP////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000101062343&amp;d='+urlencode('http://www.shinsegaetvshopping.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.shinsegaetvshopping.com</a>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=3&amp;i=nad-a001-01-000000101062343&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">삼성전자</strong>, 첫구매 10% 할인쿠폰 &amp; 신규가입 최대 5만포인트 적립!
#             </p></div>
# </div>
# </li>
# <li class="lst lst4" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=I3G2JRi9ANkQet1KircZQ////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000103891721&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">삼성전자,롯데ON</a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=I3G2JRi9ANkQet1KircZQ////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000103891721&amp;d='+urlencode('https://www.lotteon.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteon.com</a>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=4&amp;i=nad-a001-01-000000103891721&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">삼성전자</strong> 쇼핑의 모든것! 스토어별 카드할인+추가적립에 신규회원 4종혜택까지!
#             </p></div>
# </div>
# </li>
# <li class="lst lst5" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_tit" href="https://adcr.naver.com/adcr?x=3tEmhDqtHCW+RktGXxjLLf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000114043893&amp;d=' + urlencode('https://www.eggs.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">나만의 가전제품 활용 방법 </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=3tEmhDqtHCW+RktGXxjLLf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000114043893&amp;d='+urlencode('https://www.eggs.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.eggs.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               가전기기 활용법과 노하우, TIP, 설명서, 매뉴얼, 가격정보, AS비밀 대공개!
#             </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;referenceId=U%2BEqVsp0YidsshOXTsKssssssqd-494659" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_ad"></i></a>
# </div>
# </div>
# </div>
# <script>g_crt+="&bt=7";</script>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=11&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=21&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=41&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=51&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=71&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=81&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=10&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> </link></div><div class="sub_pack" id="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_ ...

# %%
type(dom)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# - select : 여러개의 element 객체를 리스트로 가져옴
# - select_one : 하나의 element 객체를 가져옴

# %%
elements = dom.select(".lst_related_srch > li")
len(elements)
# Out:
# 10

# %%
type(elements[0].text), elements[0]
# Out:
# (str,
#  <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90%EC%9A%B0&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=1&amp;u=' + urlencode(this.href))"> <div class="tit">삼성전자우</div> </a> </li>)

# %%
keywords = [element.text.strip() for element in elements]
print(keywords)
# Out:
# ['삼성전자우', '삼성', 'lg전자', 'sk하이닉스', '카카오', '셀트리온', '엘지전자', '대한항공', '현대자동차', '코스피']

# %% [markdown]
# #### 함수로 만들어

# %%
def naver_relational_keywords(query):
    url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query={}".format(query)
    response = requests.get(url)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select(".lst_related_srch > li")
    return [element.text.strip() for element in elements]

# %%
query = "코로나"
result = naver_relational_keywords(query)
print(result)
# Out:
# ['코로나 2.5단계 연장', '코로나 라이브', '코로나 3단계', '코로나 3단계 발표', '코로나 3단계 조치', '코로나 확진자', '코로나 백신', '코로나 집합금지', '코로나 단계', '코로나 2.5단계']

# %% [markdown]
# ## 2. 다음 뉴스 데이터
# - 다음 뉴스의 메인 페이지 15개 기사의 제목, 링크, 내용 수집

# %%
# 1. URL
url = "https://news.daum.net/"

# %%
# 2. HTML(str)
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n<!DOCTYPE html>\n\n\n\n<html lang="ko" class="os_unknown none unknown version_0 ">\n<head>\n<meta charset="utf-8">\n<meta name="referrer" content="always" />\n\n<meta property="og:author" content="Daum 뉴스" />\n<meta property="og:site_name" content="다음뉴스" />\n<meta property="og:title" content="홈"/>\n<meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />\n<meta property="og:description" content="다음뉴스" />\n<link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">\n\n<title>홈 | 다음뉴스</title>\n\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/daaa468/common.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/daaa468/news.css.merged.css" />\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/daaa468/calendar.css.merged.css" />\n\n<!--[if lte IE 8]>\n<script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>\n<![endif]-->\n<!--[if lt IE 9]>\n<link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/daaa468/ie8.css.merged.css" />\n<![endif]-->\n\n<script src="//t1.daumcdn.net/media/kraken/news/daaa468/common.merged.js"></script>\n\n<script type="text/javascript" src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js"></script>\n\n<script>\n  var ENV = {\n    Profile: {\n      isProduction: \'true\' || false,\n      isSandbox: \'\' || false,\n      isCbt: \'\' || false,\n    }\n  }\n</script>\n        <script src="//t1.daumcdn.net/media/kraken/news/daaa468/homeMain.merged.js"></script>\n</head>\n<body class="bg_news">\n<div id="kakaoIndex">\n    <a href="#kakaoBody">본문 바로가기</a>\n    <a href="#kakaoGnb">메뉴 바로가기</a>\n</div>\n\n<div id="kakaoWrap" class="news_type1">\n\n<div id="kakaoHead" role="banner">\n\t<div class="head_media">\n\t\t<h1>\n\t\t\t<a href="https://news.daum.net/" id="kakaoServiceLogo" data-tiara-layer="GNB default service_news"><span class="ir_wa">뉴스</span></a>\n\t\t</h1>\n\t\t<strong class="screen_out">관련서비스</strong>\n\t\t<ul id="kakaoRelServices" data-tiara-layer="GNB default">\n\t\t\t<li><a href="https://entertain.daum.net" class="link_services link_services1" data-tiara-layer="service_enter"><span class="ir_wa">연예</span></a></li>\n\t\t\t<li><a href="https://sports.daum.net" class="link_services link_services2" data-tiara-layer="service_sports"><span class="ir_wa">스포츠</span></a></li>\n\t\t</ul>\n<h2 class="screen_out">검색</h2>\n<div class="search_news" id="search_news">\n\t<form id="kakaoSearch" name="kakaoSearch" action="//search.daum.net/search" method="get">\n\t\t<fieldset class="fld_inside">\n\t\t\t<legend class="screen_out">검색어 입력폼</legend>\n\t\t\t<div class="box_searchbar">\n\t\t\t\t<label for="qVal" class="lab_search">통합검색</label>\n\t\t\t\t<input type="hidden" name="DA" value="23A" />\n\t\t\t\t<input type="hidden" name="rtmaxcoll" value="NNS">\n\t\t\t\t<input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">\n\t\t\t\t<button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>\n\t\t\t</div>\n\t\t</fieldset>\n\t\t<div id="wrap_suggestBox" class="wrap_suggestBox">\n\t\t\t<div id="suggestBox" class="suggestBox box_sub">\n\t\t\t\t<div class="baseBox bg" style="display: none"></div>\n\t\t\t</div>\n\t\t</div>\n\t</form>\n</div>\n<script type="text/javascript" src="https://search1.daumcdn.net/search/suggest_pc/suggest-1.2.16.min.js"></script>\n<script src="//t1.daumcdn.net/media/kraken/news/daaa468/suggest.merged.js"></script>\n\n\t</div>\n\n\t<div id="kakaoGnb" role="navigation">\n\t\t<div class="inner_gnb">\n\t\t\t<h2 class="screen_out">뉴스 메인메뉴</h2>\n\t\t\t<ul class="gnb_comm" data-tiara-layer="GNB default">\n\t\t\t\t<li class="on"><a href="/" class="link_gnb link_gnb1" data-tiara-layer="media_home"><span class=" ...

# %%
# 3. BS
dom = BeautifulSoup(response.content, "html.parser")
dom
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/daaa468/common.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/daaa468/news.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/daaa468/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# <script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>
# <![endif]-->
# <!--[if lt IE 9]>
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/daaa468/ie8.css.merged.css" />
# <![endif]-->
# <script src="//t1.daumcdn.net/media/kraken/news/daaa468/common.merged.js"></script>
# <script src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>
#   var ENV = {
#     Profile: {
#       isProduction: 'true' || false,
#       isSandbox: '' || false,
#       isCbt: '' || false,
#     }
#   }
# </script>
# <script src="//t1.daumcdn.net/media/kraken/news/daaa468/homeMain.merged.js"></script>
# </link></meta></head>
# <body class="bg_news">
# <div id="kakaoIndex">
# <a href="#kakaoBody">본문 바로가기</a>
# <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="news_type1" id="kakaoWrap">
# <div id="kakaoHead" role="banner">
# <div class="head_media">
# <h1>
# <a data-tiara-layer="GNB default service_news" href="https://news.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a>
# </h1>
# <strong class="screen_out">관련서비스</strong>
# <ul data-tiara-layer="GNB default" id="kakaoRelServices">
# <li><a class="link_services link_services1" data-tiara-layer="service_enter" href="https://entertain.daum.net"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services link_services2" data-tiara-layer="service_sports" href="https://sports.daum.net"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="//search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside">
# <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar">
# <label class="lab_search" for="qVal">통합검색</label>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/>
# <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# <script src="https://search1.daumcdn.net/search/suggest_pc/suggest-1.2.16.min.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/media/kraken/news/daaa468/suggest.merged.js"></script>
# </div>
# <div id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-tiara-layer="GNB default">
# <li class="on"><a class="link_gnb link_gnb1" data-tiara-layer="media_home" href="/"><span class="screen_out">선택됨</span><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li> <a class="link_gnb link_gnb2" data-tiara-layer="media_society" href="/society"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb3" data-tiara-layer="media_politics" href="/politics"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb4" data-tiara-layer="media_economic" href="/economic"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb5" data-tiara-layer="media_foreign" href="/foreign"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb6" data-tiara-layer="media_culture" href="/culture"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb7" data-tiara-layer="media_digital" href="/digital"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb8" data-tiara-layer="media_ranking" href="/ranking/popular"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb9" data-tiara-layer="media_series" href="/series/"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb10" data-tiara-layer="media_photo" href="/photo"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li><a class="link_gnb link_gnb11" data-tiara-layer="media_tv" href="/tv/"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_etc">
# <ul class="gnb_with" data-tiara-layer="GNB default">
# <li><a class="link_gnb link_gnb1" data-tiara-layer="media_1boon" href="/1boon"><span class="ir_wa">1boon</span></a></li>
# <li><a class="link_gnb link_gnb2" data-tiara-layer="media_exhibition" href="https://gallery.v.daum.net/p/home"><span class="ir_wa">갤러리</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# </ul>
# <div class="gnb_weather">
# <strong class="screen_out">날씨 정보</strong>
# <ul class="list_weather type_night">
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=서울특별시날씨">
# <span class="ico_weather ico_weather3">구름많음</span>
# <span class="txt_weather">
# 											서울
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=수원시 권선구날씨">
# <span class="ico_weather ico_weather18">안개</span>
# <span class="txt_weather">
# 											수원
# 											<span class="num_heat">6</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=인천광역시날씨">
# <span class="ico_weather ico_weather18">안개</span>
# <span class="txt_weather">
# 											인천
# 											<span class="num_heat">5</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=대구광역시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											대구
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=대전광역시날씨">
# <span class="ico_weather ico_weather3">구름많음</span>
# <span class="txt_weather">
# 											대전
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=광주광역시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											광주
# 											<span class="num_heat">7</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=부산광역시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											부산
# 											<span class="num_heat">9</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=울산광역시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											울산
# 											<span class="num_heat">10</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=울릉군날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											울릉/독도
# 											<span class="num_heat">7</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=춘천시날씨">
# <span class="ico_weather ico_weather4">흐림</span>
# <span class="txt_weather">
# 											춘천
# 											<span class="num_heat">5</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=강릉시날씨">
# <span class="ico_weather ico_weather4">흐림</span>
# <span class="txt_weather">
# 											강릉
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=백령면날씨">
# <span class="ico_weather ico_weather4">흐림</span>
# <span class="txt_weather">
# 											백령
# 											<span class="num_heat">5</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=청주시 상당구날씨">
# <span class="ico_weather ico_weather4">흐림</span>
# <span class="txt_weather">
# 											청주
# 											<span class="num_heat">4</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=전주시 완산구날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											전주
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=목포시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											목포
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=여수시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											여수
# 											<span class="num_heat">9</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=제주특별자치도날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											제주
# 											<span class="num_heat">11</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=안동시날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											안동
# 											<span class="num_heat">5</span> ℃
#                                 		</span>
# </a>
# </li>
# <li>
# <a class="link_cont" data-tiara-layer="GNB default widget_weather" href="http://search.daum.net/search?w=tot&amp;DA=23W&amp;rtmaxcoll=Z8T&amp;q=창원시 의창구날씨">
# <span class="ico_weather ico_weather1">맑음</span>
# <span class="txt_weather">
# 											창원
# 											<span class="num_heat">8</span> ℃
#                                 		</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <script src="//t1.daumcdn.net/media/kraken/news/daaa468/gnb.merged.js"></script>
# <style>
# 		.gnb_comm .link_gnb .bar_gnb .inner_bar {width:0;background-color:#1e88e5}
# 		.gnb_comm .on .link_gnb .bar_gnb .inner_bar {width:100%}
# 	</style>
# </div>
# <hr class="hide"/>
# <div class="cont_home" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">홈</h2>
# <div id="cSub">
# <div class="feature_home">
# <ul class="list_issue" data-tiara-layer="MCC">
# <li data-tiara-layer="cluster1">
# <div class="item_issue">
# <a class="link_thumb" data-tiara-custom="contentUniqueKey=hamny-20201228185210210" data-tiara-id="20201228185210210" data-tiara-layer="article_thumb" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228185210210">
# <img '백신="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S254x156ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fyonhap%2F20201228185210526rtfi.jpg&amp;scode=media" 벌써="" 세계각국="" 시간표'="" 압박"="" 접종하는데"..野=""/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228185210210" data-tiara-id="20201228185210210" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228185210210">"세계각국 벌써 접종하는데"..野 '백신 시간표' 압박</a>
# </strong>
# <span class="info_thumb">연합뉴스</span>
# </div>
# </div>
# <div class="relate_thumb"><!-- 연관기사가 있을경우 노출 -->
# <strong class="screen_out">연관 기사</strong>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228182943787" data-tiara-id="20201228182943787" data-tiara-layer="article_sub" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228182943787">文 반박한 유승민 "백신 확보 실패, 접종 늦어진 건 '사실'"</a>
# <span class="info_news">중앙일보</span>
# </div>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228165131802" data-tiara-id="20201228165131802" data-tiara-layer="article_sub" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228165131802">'백신 실기론' 적극 반박 文, "도입도 접종도 늦지 않다"</a>
# <span class="info_news">한국일보</span>
# </div>
# </div>
# </li>
# <li data-tiara-layer="cluster2">
# <div class="item_issue">
# <a class="link_thumb" data-tiara-custom="contentUniqueKey=hamny-20201228185139201" data-tiara-id="20201228185139201" data-tiara-layer="article_thumb" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228185139201">
# <img alt="서울동부구치소 233명 추가 확진..누적 748명" class="thumb_g" src="https://img1.daumcdn.net/thumb/S254x156ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2FNEWS1%2F20201228185140133ldsp.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228185139201" data-tiara-id="20201228185139201" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228185139201">서울동부구치소 233명 추가 확진..누적 748명</a>
# </strong>
# <span class="info_thumb">뉴스1</span>
# </div>
# </div>
# <div class="relate_thumb"><!-- 연관기사가 있을경우 노출 -->
# <strong class="screen_out">연관 기사</strong>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228154103299" data-tiara-id="20201228154103299" data-tiara-layer="article_sub" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228154103299">동부구치소 확진 515명..MB는 일찌감치 서울대병원</a>
# <span class="info_news">서울신문</span>
# </div>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228152657783" data-tiara-id="20201228152657783" data-tiara-layer="article_sub" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228152657783">동부구치소 확진 376명 청송 이감..MB 지병진료 입원</a>
# <span class="info_news">뉴스1</span>
# </div>
# </div>
# </li>
# <li data-tiara-layer="cluster3">
# <div class="item_issue">
# <a class="link_thumb" data-tiara-custom="contentUniqueKey=hamny-20201228184008022" data-tiara-id="20201228184008022" data-tiara-layer="article_thumb" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184008022">
# <img alt="요기요 매각 강수둔 공정위 왜? " class="thumb_g" src="https://img1.daumcdn.net/thumb/S254x156ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2FEdaily%2F20201228184010778sbim.jpg&amp;scode=media" 경쟁자="" 아냐""="" 유력="" 쿠팡·네이버,=""/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184008022" data-tiara-id="20201228184008022" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184008022">요기요 매각 강수둔 공정위 왜? "쿠팡·네이버, 유력 경쟁자 아냐"</a>
# </strong>
# <span class="info_thumb">이데일리</span>
# </div>
# </div>
# <div class="relate_thumb"><!-- 연관기사가 있을경우 노출 -->
# <strong class="screen_out">연관 기사</strong>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228182606737" data-tiara-id="20201228182606737" data-tiara-layer="article_sub" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228182606737">공정위 결정 따라..독일 DH, '배민' 품고 '요기요' 판다</a>
# <span class="info_news">한겨레</span>
# </div>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228120249999" data-tiara-id="20201228120249999" data-tiara-layer="article_sub" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228120249999">요기요 매각명령 강수..조성욱 "경쟁제한 우려·시너지효과 모두 감안"</a>
# <span class="info_news">이데일리</span>
# </div>
# </div>
# </li>
# <li data-tiara-layer="cluster4">
# <div class="item_issue">
# <a class="link_thumb" data-tiara-custom="contentUniqueKey=hamny-20201228183817967" data-tiara-id="20201228183817967" data-tiara-layer="article_thumb" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183817967">
# <img alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S254x156ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fmoneytoday%2F20201228183819832rzmh.png&amp;scode=media" 마"..인도,="" 비공식="" 자국="" 중국인="" 지시"="" 태우지="" 항공사에=""/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183817967" data-tiara-id="20201228183817967" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183817967">"중국인 태우지 마"..인도, 자국 항공사에 비공식 지시</a>
# </strong>
# <span class="info_thumb">머니투데이</span>
# </div>
# </div>
# <div class="relate_thumb"><!-- 연관기사가 있을경우 노출 -->
# <strong class="screen_out">연관 기사</strong>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228170601368" data-tiara-id="20201228170601368" data-tiara-layer="article_sub" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228170601368">"중국인 태우지 마라"..인도 정부, 비공식 지시 내린 이유</a>
# <span class="info_news">서울신문</span>
# </div>
# <div class="thumb_relate"><!-- 개발에서 link_txt 글자수로 말줄임처리 해주세요. cp까지 합쳐서 최대 2줄노출. 뒤에 cp는 노출되면서 제목부분만 말줄임 -->
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228145055189" data-tiara-id="20201228145055189" data-tiara-layer="article_sub" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228145055189">인도 각 항공사에 "중국인 태우지 말라"</a>
# <span class="info_news">아시아경제</span>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div id="cMain">
# <div id="mArticle">
# <div class="box_headline" data-tiara-layer="MAIN_NEWS">
# <h3 class="screen_out">주요기사</h3>
# <ul class="list_headline">
# <li class="item_main">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228184840154" data-tiara-id="20201228184840154" data-tiara-layer="photo" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184840154">
# <span class="wrap_thumb">
# <img 30대="" 7시간째="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fyonhap%2F20201228184841055fggt.jpg&amp;scode=media" 건물="" 경찰과="" 남성="" 대치"="" 청주서="" 폭파하겠다"=""/>
# </span>
# <strong class="tit_g">"건물 폭파하겠다" 청주서 30대 남성 7시간째 경찰과 대치</strong>
# </a>
# </li>
# <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184301081" data-tiara-id="20201228184301081" data-tiara-layer="article" data-tiara-ordnum="5" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184301081">[단독] 어린이 활동 공간, 유해물질 기준 강화한다</a>
# <span class="info_news">EBS</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184245075" data-tiara-id="20201228184245075" data-tiara-layer="article" data-tiara-ordnum="6" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184245075">'라임 사태' 이종필, 징역 15년 구형..검찰 "초유의 사안"</a>
# <span class="info_news">뉴시스</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184116054" data-tiara-id="20201228184116054" data-tiara-layer="article" data-tiara-ordnum="7" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184116054">부산상의 차기 회장 누가 나오나..후보 3명 윤곽</a>
# <span class="info_news">연합뉴스</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184002019" data-tiara-id="20201228184002019" data-tiara-layer="article" data-tiara-ordnum="8" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184002019">서울 상위 20% 아파트값 첫 '평균 20억'..강남3구, 거래도 싹쓸이</a>
# <span class="info_news">서울경제</span>
# </strong>
# </li> </ul>
# <ul class="list_headline">
# <li class="item_main">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228184656135" data-tiara-id="20201228184656135" data-tiara-layer="photo" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184656135">
# <span class="wrap_thumb">
# <img alt="금융위, 자본시장·공인회계사법 규제 28건 개선" class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fnewsis%2F20201228184656430wmnf.jpg&amp;scode=media"/>
# </span>
# <strong class="tit_g">금융위, 자본시장·공인회계사법 규제 28건 개선</strong>
# </a>
# </li>
# <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228184001018" data-tiara-id="20201228184001018" data-tiara-layer="article" data-tiara-ordnum="9" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184001018">윤석열의 거짓말 VS 윤우진의 거짓말</a>
# <span class="info_news">뉴스타파</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183947011" data-tiara-id="20201228183947011" data-tiara-layer="article" data-tiara-ordnum="10" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183947011">공수처장 윤곽 잡히자 검찰특위 띄운 與.."2단계 개혁"</a>
# <span class="info_news">연합뉴스</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183750952" data-tiara-id="20201228183750952" data-tiara-layer="article" data-tiara-ordnum="11" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183750952">국민의힘 "소상공인·자영업자에게 최대 500만원 지원" 생존대책 제안</a>
# <span class="info_news">뉴스1</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183708936" data-tiara-id="20201228183708936" data-tiara-layer="article" data-tiara-ordnum="12" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183708936">세계 최초 수소 청소차 실증..실험적 수소도시 거듭나는 창원시</a>
# <span class="info_news">KBS</span>
# </strong>
# </li> </ul>
# <ul class="list_headline">
# <li class="item_main">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228184535119" data-tiara-id="20201228184535119" data-tiara-layer="photo" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184535119">
# <span class="wrap_thumb">
# <img alt="학교는 '어린이 제품' 안전 사각지대" class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Febs%2F20201228184537884esdh.jpg&amp;scode=media"/>
# </span>
# <strong class="tit_g">학교는 '어린이 제품' 안전 사각지대</strong>
# </a>
# </li>
# <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183606909" data-tiara-id="20201228183606909" data-tiara-layer="article" data-tiara-ordnum="13" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183606909">금값 상승률 추월한 구리, 경기회복 기대감 쏘아 올렸다</a>
# <span class="info_news">한겨레</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183449882" data-tiara-id="20201228183449882" data-tiara-layer="article" data-tiara-ordnum="14" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183449882">文대통령, 추미애 교체·공수처장 임명 함께 발표하나</a>
# <span class="info_news">뉴시스</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183413874" data-tiara-id="20201228183413874" data-tiara-layer="article" data-tiara-ordnum="15" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183413874">"재택근무 강제를" vs "격상 반대"..2.5단계 연장에 의견 '분분'</a>
# <span class="info_news">YTN</span>
# </strong>
# </li> <li>
# <strong class="tit_g">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228183300853" data-tiara-id="20201228183300853" data-tiara-layer="article" data-tiara-ordnum="16" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228183300853">"IMF, 내년 中 경제성장률 7.8% 예상, 韓 경제 훈풍 기대되나"</a>
# <span class="info_news">YTN</span>
# </strong>
# </li> </ul>
# </div>
# <div class="box_photo" data-tiara-layer="PHOTO">
# <h3 class="screen_out">포토뉴스</h3>
# <div class="gallery_list gallery_list2">
# <ul class="list_gallery">
# <li data-tiara-layer="article">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228183448881" data-tiara-id="20201228183448881" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/5014013/APkqduXQi9">
# <span class="wrap_thumb">
# <img alt="" class="thumb_g" height="142" src="https://img1.daumcdn.net/thumb/S254x142ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fyonhap%2F20201228183448169jyos.jpg&amp;scode=media" width="254"/>
# </span>
# <strong class="tit_thumb">확진자 이송 반대하는 청송 주민</strong>
# </a>
# <a class="btn_photoview" data-tiara-custom="contentUniqueKey=hamny-20201228183448881" data-tiara-id="20201228183448881" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/5014013/APkqduXQi9">
# <span class="ico_news">포토갤러리</span>
# </a>
# <span class="info_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=gallery=5014013" data-tiara-id="5014013" data-tiara-ordnum="1" data-tiara-type="gallery" href="https://gallery.v.daum.net/p/viewer/5014013/">'코로나19' 바이러스</a>
# </span>
# </li>
# <li data-tiara-layer="article">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228181656553" data-tiara-id="20201228181656553" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/1518/Asp3IyWbNm">
# <span class="wrap_thumb">
# <img alt="" class="thumb_g" height="142" src="https://img1.daumcdn.net/thumb/S254x142ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fyonhap%2F20201228181656195lwms.jpg&amp;scode=media" width="254"/>
# </span>
# <strong class="tit_thumb">달리던 화물트럭 적재함에서 불..인명피해 없어</strong>
# </a>
# <a class="btn_photoview" data-tiara-custom="contentUniqueKey=hamny-20201228181656553" data-tiara-id="20201228181656553" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/1518/Asp3IyWbNm">
# <span class="ico_news">포토갤러리</span>
# </a>
# <span class="info_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=gallery=1518" data-tiara-id="1518" data-tiara-ordnum="2" data-tiara-type="gallery" href="https://gallery.v.daum.net/p/viewer/1518/">전국 화재사고</a>
# </span>
# </li>
# <li data-tiara-layer="article">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228181123386" data-tiara-id="20201228181123386" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/379/AM9i1Zb4dF">
# <span class="wrap_thumb">
# <img alt="" class="thumb_g" height="142" src="https://img1.daumcdn.net/thumb/S254x142ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fkppa%2F20201228181124033zinc.jpg&amp;scode=media" width="254"/>
# </span>
# <strong class="tit_thumb"> 윤슬</strong>
# </a>
# <a class="btn_photoview" data-tiara-custom="contentUniqueKey=hamny-20201228181123386" data-tiara-id="20201228181123386" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/379/AM9i1Zb4dF">
# <span class="ico_news">포토갤러리</span>
# </a>
# <span class="info_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=gallery=379" data-tiara-id="379" data-tiara-ordnum="3" data-tiara-type="gallery" href="https://gallery.v.daum.net/p/viewer/379/">포토친구</a>
# </span>
# </li>
# <li data-tiara-layer="article">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228180322190" data-tiara-id="20201228180322190" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/2329/AR4GG6dUaS">
# <span class="wrap_thumb">
# <img alt="" class="thumb_g" height="142" src="https://img1.daumcdn.net/thumb/S254x142ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fmk%2F20201228180322154utfn.jpg&amp;scode=media" width="254"/>
# </span>
# <strong class="tit_thumb"> 변이 코로나 유입에 인천공항 비상</strong>
# </a>
# <a class="btn_photoview" data-tiara-custom="contentUniqueKey=hamny-20201228180322190" data-tiara-id="20201228180322190" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://gallery.v.daum.net/p/viewer/2329/AR4GG6dUaS">
# <span class="ico_news">포토갤러리</span>
# </a>
# <span class="info_thumb">
# <a class="link_txt" data-tiara-custom="contentUniqueKey=gallery=2329" data-tiara-id="2329" data-tiara-ordnum="4" data-tiara-type="gallery" href="https://gallery.v.daum.net/p/viewer/2329/">영국은 지금</a>
# </span>
# </li>
# </ul>
# </div>
# </div>
# <div class="box_peruse" data-tiara-layer="DRI">
# <div class="pop_news pop_cmt">
# <h3 class="tit_news">열독률 높은 뉴스</h3>
# <ol class="list_popcmt">
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228075638367" data-tiara-id="20201228075638367" data-tiara-layer="article" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20201228075638367">
# <span class="num_news num1">1 위</span>
#                             저감장치 미개발 5등급차, 1월부터 단속 '주의'
#                         </a>
# <span class="info_news">오토타임즈</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228154917656" data-tiara-id="20201228154917656" data-tiara-layer="article" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://v.daum.net/v/20201228154917656">
# <span class="num_news num2">2 위</span>
#                             '1심 징역 8년' 미성년 성폭행 사건, 항소심서 '무죄'로 뒤집혀
#                         </a>
# <span class="info_news">연합뉴스</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228143518318" data-tiara-id="20201228143518318" data-tiara-layer="article" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://v.daum.net/v/20201228143518318">
# <span class="num_news num3">3 위</span>
#                             "초등학교 교실내 교사 불륜행각"..전북교육청 직접감사 착수
#                         </a>
# <span class="info_news">이데일리</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228073010049" data-tiara-id="20201228073010049" data-tiara-layer="article" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://v.daum.net/v/20201228073010049">
# <span class="num_news num4">4 위</span>
#                             신호 대기 차량 덮친 음주운전 참사..50대 가장 하반신 마비
#                         </a>
# <span class="info_news">연합뉴스</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228091800484" data-tiara-id="20201228091800484" data-tiara-layer="article" data-tiara-ordnum="5" data-tiara-type="harmony" href="https://v.daum.net/v/20201228091800484">
# <span class="num_news num5">5 위</span>
#                             [취재파일] 잠수함 · KF-X '인니 리스크'..'유턴' 방사청장의 최대 과제
#                         </a>
# <span class="info_news">SBS</span>
# </li>
# </ol>
# <a class="link_more" data-tiara-layer="more" href="/ranking/kkomkkom/">전체보기</a>
# </div>
# </div>
# <div class="box_g box_popnews">
# <div class="pop_news pop_cmt" data-tiara-layer="BESTREPLY">
# <h3 class="tit_news">댓글 많은 뉴스</h3>
# <ol class="list_popcmt">
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228164015478" data-tiara-id="20201228164015478" data-tiara-layer="article" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228164015478">
# <span class="num_news num1">1 위</span>
#                         檢, 정경심 측 증인들 위증 수사 나선다..법조계 "김두관·유시민 등 허위진술 요구 의혹도 수사해야"
#                     </a>
# <span class="info_news">문화일보</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228172438930" data-tiara-id="20201228172438930" data-tiara-layer="article" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228172438930">
# <span class="num_news num2">2 위</span>
#                         '박원순 피해자' 편지 공개 여파..시민단체 촉구 이어 연서명도
#                     </a>
# <span class="info_news">뉴스1</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228170212245" data-tiara-id="20201228170212245" data-tiara-layer="article" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228170212245">
# <span class="num_news num3">3 위</span>
#                         '지지율 급락' 文, 이르면 29일 秋 교체..노영민·김상조, 내달 동반퇴진(종합)
#                     </a>
# <span class="info_news">이데일리</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228174159435" data-tiara-id="20201228174159435" data-tiara-layer="article" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228174159435">
# <span class="num_news num4">4 위</span>
#                         문대통령, 변창흠·정영애 임명 재가..29일부터 임기 시작
#                     </a>
# <span class="info_news">뉴스1</span>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228170632395" data-tiara-id="20201228170632395" data-tiara-layer="article" data-tiara-ordnum="5" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228170632395">
# <span class="num_news num5">5 위</span>
#                         서민 "정경심 재판부 탄핵? 대통령 탄핵이 먼저"
#                     </a>
# <span class="info_news">동아일보</span>
# </li>
# </ol>
# <a class="link_more" data-tiara-layer="more" href="/ranking/bestreply/">전체보기</a>
# </div>
# <div class="pop_news pop_age" data-tiara-layer="AGE">
# <h3 class="tit_news">연령별 인기뉴스</h3>
# <div class="agenews_list" data-tiara-layer="popular_female">
# <span class="txt_news ico_female">여성 인기 뉴스 목록</span>
# <ul class="list_agenews list_female">
# <li>
# <span class="txt_news ico_age20">20대</span>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228150312842" data-tiara-id="20201228150312842" data-tiara-layer="article" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20201228150312842">'이미지와 너무 다른 케이크' 고객 항의에..'갑질' 걱정하는 가맹본부</a>
# </li>
# <li>
# <span class="txt_news ico_age30">30대</span>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228154011271" data-tiara-id="20201228154011271" data-tiara-layer="article" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://v.daum.net/v/20201228154011271">[단독]'자가격리 중 생일파티' 유튜버 국가비 기소의견 檢 송치</a>
# </li>
# <li>
# <span class="txt_news ico_age40">40대</span>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228172422922" data-tiara-id="20201228172422922" data-tiara-layer="article" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://v.daum.net/v/20201228172422922">학원연합회 "내년 1월3일 이후 운영중단 계속되면 2차 행정소송"</a>
# </li>
# <li>
# <span class="txt_news ico_age50">50대</span>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228173601249" data-tiara-id="20201228173601249" data-tiara-layer="article" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://v.daum.net/v/20201228173601249">속헹씨 시신 발견한 동료들, 여전히 비닐하우스에 산다</a>
# </li>
# </ul>
# </div>
# <div class="agenews_list" data-tiara-layer="popular_male">
# <span class="txt_news ico_male">남성 인기 뉴스 목록</span>
# <ul class="list_agenews list_male">
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228180645286" data-tiara-id="20201228180645286" data-tiara-layer="article" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20201228180645286">"어..운전석이 비어있는 택시가 움직여?" 온몸으로 막아선 경찰</a>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228182137649" data-tiara-id="20201228182137649" data-tiara-layer="article" data-tiara-ordnum="2" data-tiara-type="harmony" href="https://v.daum.net/v/20201228182137649">[단독] 셀트리온 부회장·전무 주식 팔아 챙겼는데 ..뒤늦게 팔지마 '뒷북'</a>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228160103115" data-tiara-id="20201228160103115" data-tiara-layer="article" data-tiara-ordnum="3" data-tiara-type="harmony" href="https://v.daum.net/v/20201228160103115">당장 병원에 가야 할 증상 5</a>
# </li>
# <li>
# <a class="link_txt" data-tiara-custom="contentUniqueKey=hamny-20201228172438930" data-tiara-id="20201228172438930" data-tiara-layer="article" data-tiara-ordnum="4" data-tiara-type="harmony" href="https://v.daum.net/v/20201228172438930">'박원순 피해자' 편지 공개 여파..시민단체 촉구 이어 연서명도</a>
# </li>
# </ul>
# </div>
# <a class="link_more" data-tiara-layer="more" href="/ranking/age/">전체보기</a>
# </div>
# </div>
# </div>
# <div id="mAside" role="complementary">
# <div class="aside_g aside_ad" style="height:250px">
# <h3 class="screen_out">광고</h3>
# <ins class="kakao_ad_area" data-ad-frame-id="AMS_250exp" data-ad-frame-name="AMS_250exp" data-ad-height="250" data-ad-param-channel="media" data-ad-param-cp="pc_media_news" data-ad-type="D" data-ad-unit="05d22" data-ad-width="250" style="display:block"></ins>
# </div>
# <div class="aside_g aside_today" data-tiara-layer="RIGHT today">
# <h3 class="tit_news">TODAY</h3>
# <div class="cont_aside">
# <ul class="list_economic">
# <li class="item_up">
# <strong class="tit_g"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스피" target="_blank">코스피</a></strong>
# <span class="num_index"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스피" target="_blank">2,808.60<span class="screen_out">포인트</span></a></span>
# <span class="num_g num_status">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스피" target="_blank">
# <span class="ico_news2 ico_up">
#                                 1.74
#                         <span class="screen_out">상승</span>
# </span>
# </a>
# </span>
# <span class="num_g num_percent">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스피" target="_blank">0.06% <span class="screen_out">상승</span></a>
# </span>
# </li>
# <li class="item_down">
# <strong class="tit_g"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스닥" target="_blank">코스닥</a></strong>
# <span class="num_index"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스닥" target="_blank">927.00<span class="screen_out">포인트</span></a></span>
# <span class="num_g num_status">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스닥" target="_blank">
# <span class="ico_news2 ico_down">
#                                 1.68
#                         <span class="screen_out">하락</span>
# </span>
# </a>
# </span>
# <span class="num_g num_percent">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=코스닥" target="_blank">-0.18% <span class="screen_out">하락</span></a>
# </span>
# </li>
# <li class="item_up">
# <strong class="tit_g"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=다우" target="_blank">다우</a></strong>
# <span class="num_index"><a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=다우" target="_blank">30,199.87<span class="screen_out">포인트</span></a></span>
# <span class="num_g num_status">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=다우" target="_blank">
# <span class="ico_news2 ico_up">
#                                 70.04
#                         <span class="screen_out">상승</span>
# </span>
# </a>
# </span>
# <span class="num_g num_percent">
# <a class="link_txt" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=HSU&amp;q=다우" target="_blank">0.23% <span class="screen_out">상승</span></a>
# </span>
# </li>
# </ul>
# <ul class="list_today">
# <li><a class="link_today" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=B3T&amp;q=tv+%ED%8E%B8%EC%84%B1%ED%91%9C" target="_blank"><span class="txt_news txt_tv">TV 편성표</span></a></li>
# <li><a class="link_today" href="https://sports.daum.net/video/" target="_blank"><span class="txt_news txt_cast">영상센터</span></a></li>
# <li><a class="link_today" href="http://search.daum.net/search?w=tot&amp;DA=23Q&amp;rtmaxcoll=UNS&amp;q=%EC%9A%B4%EC%84%B8" target="_blank"><span class="txt_news txt_fortune">운세</span></a></li>
# </ul>
# </div>
# </div>
# <div class="aside_g aside_correction" data-tiara-layer="RIGHT correct">
# <h3 class="tit_news">바로잡습니다</h3>
# <div class="cont_aside">
# <ul class="list_txt">
# <li>
# <a class="link_txt" href="https://news.v.daum.net/v/20201224185355121">[바로잡습니다] 국민일보 24일자 12면 차관 인사 기사 관련</a>
# </li>
# <li>
# <a class="link_txt" href="https://news.v.daum.net/v/20201223160302400">(정정보도문) '여수시 웅천지역 어린이집 아동학대의혹 "진실"은 보도관련</a>
# </li>
# <li>
# <a class="link_txt" href="https://news.v.daum.net/v/20201222140027551">["'검-언 유착' 실체 규명되나" 관련 정정보도문]</a>
# </li>
# <li>
# <a class="link_txt" href="https://news.v.daum.net/v/20201212074906770">정정보도문</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="aside_shopping">
# <h3 class="screen_out">쇼핑</h3>
# <div class="cont_aside">
# <div id="daum-sfocus-root"></div>
# </div>
# </div>
# <script>
#         daum_sfocus_adunit = "DAU-e21ba8e41";
#         daum_sfocus_cp = "pc_media_news";
#         daum_sfocus_channel = "media";
#
#         (function (d) {
#             var a = d.createElement('script');
#             a.type = 'text/javascript';
#             a.async = true;
#             a.src = 'https://keyword.ad.daum.net/script/load_sfocus.js';
#             var s = d.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(a, s);
#         })(self.document);
#     </script>
# </div>
# </div>
# </div>
# <hr class="hide"/>
# <div class="footer_comm" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot #FOOTER" data-tiara-layer="FOOTER">
# <div class="direct_link #direct" data-tiara-layer="direct">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle">
# <a class="link_txt #direct_newshome" data-tiara-layer="direct_newshome" href="/">뉴스홈</a>
# <a class="link_txt #direct_society" data-tiara-layer="direct_society" href="/society" style="display: none;">사회</a>
# <a class="link_txt #direct_politics" data-tiara-layer="direct_politics" href="/politics" style="display: none;">정치</a>
# <a class="link_txt #direct_economic" data-tiara-layer="direct_economic" href="/economic" style="display: none;">경제</a>
# <a class="link_txt #direct_foreign" data-tiara-layer="direct_foreign" href="/foreign" style="display: none;">국제</a>
# <a class="link_txt #direct_culture" data-tiara-layer="direct_culture" href="/culture" style="display: none;">문화</a>
# <a class="link_txt #direct_digital" data-tiara-layer="direct_digital" href="/digital" style="display: none;">IT</a>
# <a class="link_txt #direct_photo" data-tiara-layer="direct_photo" href="/photo" style="display: none;">포토</a>
# <a class="link_txt #direct_tv" data-tiara-layer="direct_tv" href="/tv" style="display: none;">TV</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_media" data-tiara-layer="direct_media" href="/cp">언론사별 뉴스</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_history" data-tiara-layer="direct_history" href="/newsbox">배열이력</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_all" data-tiara-layer="direct_all" href="/breakingnews">전체뉴스</a>
# <a class="link_txt #direct_rank" data-tiara-layer="direct_rank" href="/ranking/popular" style="display: none;">랭킹</a>
# <a class="link_txt #direct_series" data-tiara-layer="direct_series" href="/series" style="display: none;">연재</a>
# <a class="link_txt #direct_1boon" data-tiara-layer="direct_1boon" href="/1boon" style="display: none;">1boon</a>
# </div>
# <button class="btn_fold" style="outline: 0px;" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link">
# <a class="link_info #info_daumnews" data-tiara-layer="info_daumnews" href="/info/intro">다음뉴스 소개</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #notice" data-tiara-layer="notice" href="/notice">공지사항</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #bbsrule" data-tiara-layer="bbsrule" href="/info/bbsrule">게시물 운영원칙</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #policy" data-tiara-layer="policy" href="http://policy.daum.net/info/info">서비스 약관/정책</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #harmony" data-tiara-layer="harmony" href="https://with.kakao.com/media">뉴스제휴</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #adinfo" data-tiara-layer="adinfo" href="https://business.kakao.com">비즈니스</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #redbell" data-tiara-layer="redbell" href="https://cs.daum.net/redbell/top.html">권리침해신고</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #consumer" data-tiara-layer="consumer" href="http://cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link">
# <a class="link_info #newscenter" data-tiara-layer="newscenter" href="/info/newscenter24">24시간 뉴스센터</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #edit" data-tiara-layer="edit" href="/info/edit">서비스원칙</a> <span class="txt_dot"> ・ </span>
# <a class="link_info #correct" data-tiara-layer="correct" href="/info/correct">바로잡습니다</a> <span class="txt_dot"> ・ </span>
# <span class="link_info">기사배열책임자 : 김희정</span> <span class="txt_dot"> ・ </span>
# <span class="link_info">청소년보호책임자 : 이준목</span>
# </div>
# <div class="info_copyright">
# <strong class="info_warn">뉴스 기사에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
# <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div>
# <div id="wrapMinidaum"></div>
# <script type="text/javascript">
# 	var minidaum_options = {
# 		bgType				: "white",
# 		enableLogoutRetun	: true,
# 		disableTracker		: true, // false일 경우 사용, true일 경우 미사용
# 		enableShield		: false
# 	};
# </script>
# <script src="https://go.daum.net/minidaum_pc.daum"></script>
# <script src="//t1.daumcdn.net/media/kraken/news/daaa468/footer.merged.js"></script>
# <script async="" src="//t1.daumcdn.net/kas/static/ba.min.js" type="text/javascript"></script>
# </div>
# </body>
# </html>

# %%
elements = dom.select(".list_headline > li")
len(elements)
# Out:
# 15

# %%
elements[0]
# Out:
# <li class="item_main">
# <a class="link_cont" data-tiara-custom="contentUniqueKey=hamny-20201228184840154" data-tiara-id="20201228184840154" data-tiara-layer="photo" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://news.v.daum.net/v/20201228184840154">
# <span class="wrap_thumb">
# <img 30대="" 7시간째="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S189x104ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202012%2F28%2Fyonhap%2F20201228184841055fggt.jpg&amp;scode=media" 건물="" 경찰과="" 남성="" 대치"="" 청주서="" 폭파하겠다"=""/>
# </span>
# <strong class="tit_g">"건물 폭파하겠다" 청주서 30대 남성 7시간째 경찰과 대치</strong>
# </a>
# </li>

# %%
datas = []

for element in elements:
    datas.append({
        "title": element.select_one(".tit_g").text.strip().replace("\n",""),
        "link" : element.select_one("a").get("href"),
    })
    
articles_df = pd.DataFrame(datas)
articles_df.tail(2)
# Out:
#                                           title  \
# 13  "재택근무 강제를" vs "격상 반대"..2.5단계 연장에 의견 '분분'YTN
# 14   "IMF, 내년 中 경제성장률 7.8% 예상, 韓 경제 훈풍 기대되나"YTN
#
#                                            link
# 13  https://news.v.daum.net/v/20201228183413874
# 14  https://news.v.daum.net/v/20201228183300853

# %% [markdown]
# #### content 데이터 추가

# %%
link = articles_df.loc[0, "link"]
print(link)
# Out:
# https://news.v.daum.net/v/20201228184840154

# %%
response = requests.get(link)
dom = BeautifulSoup(response.content, "html.parser")

# %%
dom.select_one("#harmonyContainer").text.strip().replace("\n"," ")
# Out:
# '(청주=연합뉴스) 천경환 기자 = 청주의 한 상가 건물에서 30대 남성이 내부에 휘발유를 뿌리고 폭파 협박을 하면서 경찰과 7시간 넘게 대치하고 있다. 28일 경찰 등에 따르면 이날 오전 11시 10분께 청주시 청원구 율량동 4층짜리 건물 3층의 헬스장에 A씨가 난입해 바닥 등에 휘발유를 뿌리고 문을 부수는 등 난동을 부렸다.                청주 율량동서 30대 남성 난동 [촬영 천경환 기자]              A씨는 "헬스장 관장에게 사기를 당했다. 러시아 대통령의 지시를 받고 건물을 폭파하러 왔다"는 등 횡설수설하면서 경찰·소방당국과 대치하고 있다.  이 과정에서 A씨는 부탄가스에 불을 붙여 건물 밖으로 던지고, 건물에 진입하려는 소방관에게 깨진 유리와 운동기구 등을 던지기도 했다. 경찰은 위험 상황에 대비해 헬스장 직원 등 20여명을 대피시켰다. A씨는 이 헬스장 회원은 아닌 것으로 전해졌다 경찰은 "혹시 모를 사고에 대비해 헬스장에 진입하는 대신 A씨가 흥분을 가라앉힌 뒤 스스로 밖으로 나오도록 설득하고 있다"고 말했다.                 청주 율량동서 30대 남성 난동 [촬영 천경환 기자]              kw@yna.co.kr'

# %%
def get_content(link):
    response = requests.get(link)
    dom = BeautifulSoup(response.content, "html.parser")
    return dom.select_one("#harmonyContainer").text.strip().replace("\n"," ")

# %%
articles_df["content"] = articles_df["link"].apply(get_content)
articles_df.tail(2)
# Out:
#                                           title  \
# 13  "재택근무 강제를" vs "격상 반대"..2.5단계 연장에 의견 '분분'YTN
# 14   "IMF, 내년 中 경제성장률 7.8% 예상, 韓 경제 훈풍 기대되나"YTN
#
#                                            link  \
# 13  https://news.v.daum.net/v/20201228183413874
# 14  https://news.v.daum.net/v/20201228183300853
#
#                                               content
# 13  [앵커]  거리 두기는 이번 주도 3단계로 올라가지 않았습니다.  수도권은 2.5단...
# 14  ■ 방송 : YTN 라디오 FM 94.5 (15:10~16:00)  ■ 날짜 : 2...
